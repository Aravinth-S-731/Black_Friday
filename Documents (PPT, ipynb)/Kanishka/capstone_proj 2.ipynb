# %% [raw]
# --> DATA MANUPULATION
# -->DATA CLEANING

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,accuracy_score,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
ds1=pd.read_csv('Retail_datasets_P2/User_product_purchase_details_p2.csv')

# %%
ds1
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 0       1000001  P00069042             A                          2
# 1       1000001  P00248942             A                          2
# 2       1000001  P00087842             A                          2
# 3       1000001  P00085442             A                          2
# 4       1000002  P00285442             C                         4+
# ...         ...        ...           ...                        ...
# 550063  1006033  P00372445             B                          1
# 550064  1006035  P00375436             C                          3
# 550065  1006036  P00375436             B                         4+
# 550066  1006038  P00375436             C                          2
# 550067  1006039  P00371644             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 NaN
# 1                    0                   1                 6.0
# 2                    0                  12                 NaN
# 3                    0                  12                14.0
# 4                    0                   8                 NaN
# ...                ...                 ...                 ...
# 550063               1                  20                 NaN
# 550064               0                  20                 NaN
# 550065               1                  20                 NaN
# 550066               0                  20                 NaN
# 550067               1                  20                 NaN
#
#         Product_Category_3  Purchase
# 0                      NaN      8370
# 1                     14.0     15200
# 2                      NaN      1422
# 3                      NaN      1057
# 4                      NaN      7969
# ...                    ...       ...
# 550063                 NaN       368
# 550064                 NaN       371
# 550065                 NaN       137
# 550066                 NaN       365
# 550067                 NaN       490
#
# [550068 rows x 9 columns]

# %%
ds2=pd.read_csv('Retail_datasets_P2/user_demographics.csv')

# %%
ds2
# Out:
#       User_ID Gender    Age  Occupation
# 0     1000001      F   0-17          10
# 1     1000002      M    55+          16
# 2     1000003      M  26-35          15
# 3     1000004      M  46-50           7
# 4     1000005      M  26-35          20
# ...       ...    ...    ...         ...
# 5886  1004588      F  26-35           4
# 5887  1004871      M  18-25          12
# 5888  1004113      M  36-45          17
# 5889  1005391      M  26-35           7
# 5890  1001529      M  18-25           4
#
# [5891 rows x 4 columns]

# %%
ds=pd.merge(ds1,ds2,on='User_ID')

# %%
ds
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 0       1000001  P00069042             A                          2
# 1       1000001  P00248942             A                          2
# 2       1000001  P00087842             A                          2
# 3       1000001  P00085442             A                          2
# 4       1000002  P00285442             C                         4+
# ...         ...        ...           ...                        ...
# 550063  1006033  P00372445             B                          1
# 550064  1006035  P00375436             C                          3
# 550065  1006036  P00375436             B                         4+
# 550066  1006038  P00375436             C                          2
# 550067  1006039  P00371644             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 NaN
# 1                    0                   1                 6.0
# 2                    0                  12                 NaN
# 3                    0                  12                14.0
# 4                    0                   8                 NaN
# ...                ...                 ...                 ...
# 550063               1                  20                 NaN
# 550064               0                  20                 NaN
# 550065               1                  20                 NaN
# 550066               0                  20                 NaN
# 550067               1                  20                 NaN
#
#         Product_Category_3  Purchase Gender    Age  Occupation
# 0                      NaN      8370      F   0-17          10
# 1                     14.0     15200      F   0-17          10
# 2                      NaN      1422      F   0-17          10
# 3                      NaN      1057      F   0-17          10
# 4                      NaN      7969      M    55+          16
# ...                    ...       ...    ...    ...         ...
# 550063                 NaN       368      M  51-55          13
# 550064                 NaN       371      F  26-35           1
# 550065                 NaN       137      F  26-35          15
# 550066                 NaN       365      F    55+           1
# 550067                 NaN       490      F  46-50           0
#
# [550068 rows x 12 columns]

# %%
ds.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# Gender                             0
# Age                                0
# Occupation                         0
# dtype: int64

# %%
ds['Product_Category_1']=ds['Product_Category_1'].fillna(0)
ds['Product_Category_2']=ds['Product_Category_2'].fillna(0)
ds['Product_Category_3']=ds['Product_Category_3'].fillna(0)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   City_Category               550068 non-null  object
#  3   Stay_In_Current_City_Years  550068 non-null  object
#  4   Marital_Status              550068 non-null  int64
#  5   Product_Category_1          550068 non-null  int64
#  6   Product_Category_2          550068 non-null  float64
#  7   Product_Category_3          550068 non-null  float64
#  8   Purchase                    550068 non-null  int64
#  9   Gender                      550068 non-null  object
#  10  Age                         550068 non-null  object
#  11  Occupation                  550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
ds[['Product_Category_2','Product_Category_3']]=ds[['Product_Category_2','Product_Category_3']].astype(int)

# %%
#spliting the age range into int(age)
ds['start']=ds['Age'].str.split('-').str[0]
ds['end']=ds['Age'].str.split('-').str[1]

#+ is present so replace
ds['start']=ds['start'].str.replace('+','',regex=False)

#for null val in end of range replace with start 
ds['end']=ds['end'].fillna(ds['start'])

#convert to int datatype
ds['start']=ds['start'].astype(int)
ds['end']=ds['end'].astype(int)

#finding median
ds['Age']=(ds['start']+ds['end'])/2
#drop the temp col
ds.drop(['start','end'],axis=1,inplace=True)
ds["Age"]=ds['Age'].astype(int)

# %%
ds['Purchase'].mean()
# Out:
# np.float64(9263.968712959126)

# %%
mean=ds['Purchase'].mean()
def voucher(purchase):
    if purchase > mean:
         dis=purchase*0.25
         return purchase-dis
         
    else:
        return purchase
ds['After_discount']=ds['Purchase'].apply(voucher)

# %%
ds
# Out:
#         User_ID Product_ID City_Category Stay_In_Current_City_Years  \
# 0       1000001  P00069042             A                          2
# 1       1000001  P00248942             A                          2
# 2       1000001  P00087842             A                          2
# 3       1000001  P00085442             A                          2
# 4       1000002  P00285442             C                         4+
# ...         ...        ...           ...                        ...
# 550063  1006033  P00372445             B                          1
# 550064  1006035  P00375436             C                          3
# 550065  1006036  P00375436             B                         4+
# 550066  1006038  P00375436             C                          2
# 550067  1006039  P00371644             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                   0
# 1                    0                   1                   6
# 2                    0                  12                   0
# 3                    0                  12                  14
# 4                    0                   8                   0
# ...                ...                 ...                 ...
# 550063               1                  20                   0
# 550064               0                  20                   0
# 550065               1                  20                   0
# 550066               0                  20                   0
# 550067               1                  20                   0
#
#         Product_Category_3  Purchase Gender  Age  Occupation  After_discount
# 0                        0      8370      F    8          10          8370.0
# 1                       14     15200      F    8          10         11400.0
# 2                        0      1422      F    8          10          1422.0
# 3                        0      1057      F    8          10          1057.0
# 4                        0      7969      M   55          16          7969.0
# ...                    ...       ...    ...  ...         ...             ...
# 550063                   0       368      M   53          13           368.0
# 550064                   0       371      F   30           1           371.0
# 550065                   0       137      F   30          15           137.0
# 550066                   0       365      F   55           1           365.0
# 550067                   0       490      F   48           0           490.0
#
# [550068 rows x 13 columns]

# %%
grp_ds=ds[['User_ID','Gender','Age','Occupation','Product_ID','City_Category','Stay_In_Current_City_Years','Marital_Status','Product_Category_1','Product_Category_2','Product_Category_3','Purchase','After_discount']].groupby('User_ID').sum()

# %%
grp_ds
# Out:
#                                                     Gender    Age  Occupation  \
# User_ID
# 1000001                FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF    280         350
# 1000002  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...   4235        1232
# 1000003                      MMMMMMMMMMMMMMMMMMMMMMMMMMMMM    870         435
# 1000004                                     MMMMMMMMMMMMMM    672          98
# 1000005  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...   3180        2120
# ...                                                    ...    ...         ...
# 1006036  FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...  15420        7710
# 1006037  FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...   5856         122
# 1006038                                       FFFFFFFFFFFF    660          12
# 1006039  FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...   3552           0
# 1006040  MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...   5400        1080
#
#                                                 Product_ID  \
# User_ID
# 1000001  P00069042P00248942P00087842P00085442P00085942P...
# 1000002  P00285442P00112842P00293242P00289342P00303342P...
# 1000003  P00193542P00132842P0098342P00010242P00128042P0...
# 1000004  P00184942P00346142P0097242P00046742P00329542P0...
# 1000005  P00274942P00251242P00014542P00031342P00145042P...
# ...                                                    ...
# 1006036  P00237642P00250342P00173242P00255342P00294442P...
# 1006037  P00067342P00111842P00323642P00177442P00087042P...
# 1006038  P00034742P00251242P00086042P00109542P00113442P...
# 1006039  P00114042P00199442P00088542P00254242P00101042P...
# 1006040  P00184042P00158742P00001742P00148642P00112842P...
#
#                                              City_Category  \
# User_ID
# 1000001                AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 1000002  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 1000003                      AAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# 1000004                                     BBBBBBBBBBBBBB
# 1000005  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA...
# ...                                                    ...
# 1006036  BBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBB...
# 1006037  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 1006038                                       CCCCCCCCCCCC
# 1006039  BBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBB...
# 1006040  BBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBB...
#
#                                 Stay_In_Current_City_Years  Marital_Status  \
# User_ID
# 1000001                22222222222222222222222222222222222               0
# 1000002  4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+...               0
# 1000003                      33333333333333333333333333333               0
# 1000004                                     22222222222222              14
# 1000005  1111111111111111111111111111111111111111111111...             106
# ...                                                    ...             ...
# 1006036  4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+...             514
# 1006037  4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+...               0
# 1006038                                       222222222222               0
# 1006039  4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+4+...              74
# 1006040  2222222222222222222222222222222222222222222222...               0
#
#          Product_Category_1  Product_Category_2  Product_Category_3  Purchase  \
# User_ID
# 1000001                 213                 132                 148    334093
# 1000002                 354                 539                 359    810472
# 1000003                  93                 117                 148    341635
# 1000004                  33                 102                 127    206468
# 1000005                 659                 642                 207    821001
# ...                     ...                 ...                 ...       ...
# 1006036                3200                3403                1509   4116058
# 1006037                 938                 894                 456   1119538
# 1006038                  83                  93                  51     90034
# 1006039                 439                 580                 324    590319
# 1006040                1141                1110                 455   1653299
#
#          After_discount
# User_ID
# 1000001       273151.00
# 1000002       661163.00
# 1000003       277406.00
# 1000004       155933.50
# 1000005       731065.50
# ...                 ...
# 1006036      3643821.75
# 1006037       950006.75
# 1006038        80861.50
# 1006039       510367.00
# 1006040      1398981.75
#
# [5891 rows x 12 columns]

# %%
grp_ds.drop(['Age','Gender','City_Category','Stay_In_Current_City_Years','Marital_Status','Occupation'],axis=1,inplace=True)

# %%
grp_ds.reset_index()
# Out:
#       User_ID                                         Product_ID  \
# 0     1000001  P00069042P00248942P00087842P00085442P00085942P...
# 1     1000002  P00285442P00112842P00293242P00289342P00303342P...
# 2     1000003  P00193542P00132842P0098342P00010242P00128042P0...
# 3     1000004  P00184942P00346142P0097242P00046742P00329542P0...
# 4     1000005  P00274942P00251242P00014542P00031342P00145042P...
# ...       ...                                                ...
# 5886  1006036  P00237642P00250342P00173242P00255342P00294442P...
# 5887  1006037  P00067342P00111842P00323642P00177442P00087042P...
# 5888  1006038  P00034742P00251242P00086042P00109542P00113442P...
# 5889  1006039  P00114042P00199442P00088542P00254242P00101042P...
# 5890  1006040  P00184042P00158742P00001742P00148642P00112842P...
#
#       Product_Category_1  Product_Category_2  Product_Category_3  Purchase  \
# 0                    213                 132                 148    334093
# 1                    354                 539                 359    810472
# 2                     93                 117                 148    341635
# 3                     33                 102                 127    206468
# 4                    659                 642                 207    821001
# ...                  ...                 ...                 ...       ...
# 5886                3200                3403                1509   4116058
# 5887                 938                 894                 456   1119538
# 5888                  83                  93                  51     90034
# 5889                 439                 580                 324    590319
# 5890                1141                1110                 455   1653299
#
#       After_discount
# 0          273151.00
# 1          661163.00
# 2          277406.00
# 3          155933.50
# 4          731065.50
# ...              ...
# 5886      3643821.75
# 5887       950006.75
# 5888        80861.50
# 5889       510367.00
# 5890      1398981.75
#
# [5891 rows x 7 columns]

# %%
remove_ds=ds[['User_ID','Age','Gender','City_Category','Stay_In_Current_City_Years','Marital_Status','Occupation']]

# %%
remove_ds
# Out:
#         User_ID  Age Gender City_Category Stay_In_Current_City_Years  \
# 0       1000001    8      F             A                          2
# 1       1000001    8      F             A                          2
# 2       1000001    8      F             A                          2
# 3       1000001    8      F             A                          2
# 4       1000002   55      M             C                         4+
# ...         ...  ...    ...           ...                        ...
# 550063  1006033   53      M             B                          1
# 550064  1006035   30      F             C                          3
# 550065  1006036   30      F             B                         4+
# 550066  1006038   55      F             C                          2
# 550067  1006039   48      F             B                         4+
#
#         Marital_Status  Occupation
# 0                    0          10
# 1                    0          10
# 2                    0          10
# 3                    0          10
# 4                    0          16
# ...                ...         ...
# 550063               1          13
# 550064               0           1
# 550065               1          15
# 550066               0           1
# 550067               1           0
#
# [550068 rows x 7 columns]

# %%
remove_ds=remove_ds.drop_duplicates()

# %%
remove_ds['City_Category'].isna().sum()
# Out:
# np.int64(0)

# %%
type(grp_ds)
# Out:
# pandas.core.frame.DataFrame

# %%
type(remove_ds)
# Out:
# pandas.core.frame.DataFrame

# %%
#merging the duplicate cleaned ds and grouped ds
clean_ds=pd.merge(remove_ds,grp_ds,on='User_ID')

# %%
city_mapping = {'A': 0, 'B': 1, 'C': 2}
clean_ds['City_Category'] = clean_ds['City_Category'].map(city_mapping)
clean_ds['City_Category'] = clean_ds['City_Category'].astype('int')

# %%
clean_ds
# Out:
#       User_ID  Age Gender  City_Category Stay_In_Current_City_Years  \
# 0     1000001    8      F              0                          2
# 1     1000002   55      M              2                         4+
# 2     1000003   30      M              0                          3
# 3     1000004   48      M              1                          2
# 4     1000005   30      M              0                          1
# ...       ...  ...    ...            ...                        ...
# 5886  1004588   30      F              2                          0
# 5887  1004871   21      M              2                          2
# 5888  1004113   40      M              2                          3
# 5889  1005391   30      M              0                          0
# 5890  1001529   21      M              2                         4+
#
#       Marital_Status  Occupation  \
# 0                  0          10
# 1                  0          16
# 2                  0          15
# 3                  1           7
# 4                  1          20
# ...              ...         ...
# 5886               0           4
# 5887               0          12
# 5888               0          17
# 5889               0           7
# 5890               1           4
#
#                                              Product_ID  Product_Category_1  \
# 0     P00069042P00248942P00087842P00085442P00085942P...                 213
# 1     P00285442P00112842P00293242P00289342P00303342P...                 354
# 2     P00193542P00132842P0098342P00010242P00128042P0...                  93
# 3     P00184942P00346142P0097242P00046742P00329542P0...                  33
# 4     P00274942P00251242P00014542P00031342P00145042P...                 659
# ...                                                 ...                 ...
# 5886  P00260042P00144242P00129542P00190242P00121642P...                 114
# 5887  P00242742P00321942P00286642P00286742P00295942P...                  66
# 5888  P00351842P00127642P00182342P00073842P00070442P...                  79
# 5889  P00339342P00034642P00255842P00084842P00302042P...                  40
# 5890  P00000242P00034042P00160042P00306042P00029542P...                  40
#
#       Product_Category_2  Product_Category_3  Purchase  After_discount
# 0                    132                 148    334093       273151.00
# 1                    539                 359    810472       661163.00
# 2                    117                 148    341635       277406.00
# 3                    102                 127    206468       155933.50
# 4                    642                 207    821001       731065.50
# ...                  ...                 ...       ...             ...
# 5886                 125                  20    140990       129841.00
# 5887                  83                  40    108545        89135.00
# 5888                 119                  90    213550       174646.75
# 5889                  36                  16     60182        51062.50
# 5890                  61                  96    152942       115280.50
#
# [5891 rows x 13 columns]

# %%
clean_ds['Stay_In_Current_City_Years']=clean_ds['Stay_In_Current_City_Years'].str.replace('+','')

# %%
clean_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5891 entries, 0 to 5890
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     5891 non-null   int64
#  1   Age                         5891 non-null   int64
#  2   Gender                      5891 non-null   object
#  3   City_Category               5891 non-null   int64
#  4   Stay_In_Current_City_Years  5891 non-null   object
#  5   Marital_Status              5891 non-null   int64
#  6   Occupation                  5891 non-null   int64
#  7   Product_ID                  5891 non-null   object
#  8   Product_Category_1          5891 non-null   int64
#  9   Product_Category_2          5891 non-null   int64
#  10  Product_Category_3          5891 non-null   int64
#  11  Purchase                    5891 non-null   int64
#  12  After_discount              5891 non-null   float64
# dtypes: float64(1), int64(9), object(3)
# memory usage: 598.4+ KB

# %%
clean_ds
# Out:
#       User_ID  Age Gender  City_Category Stay_In_Current_City_Years  \
# 0     1000001    8      F              0                          2
# 1     1000002   55      M              2                          4
# 2     1000003   30      M              0                          3
# 3     1000004   48      M              1                          2
# 4     1000005   30      M              0                          1
# ...       ...  ...    ...            ...                        ...
# 5886  1004588   30      F              2                          0
# 5887  1004871   21      M              2                          2
# 5888  1004113   40      M              2                          3
# 5889  1005391   30      M              0                          0
# 5890  1001529   21      M              2                          4
#
#       Marital_Status  Occupation  \
# 0                  0          10
# 1                  0          16
# 2                  0          15
# 3                  1           7
# 4                  1          20
# ...              ...         ...
# 5886               0           4
# 5887               0          12
# 5888               0          17
# 5889               0           7
# 5890               1           4
#
#                                              Product_ID  Product_Category_1  \
# 0     P00069042P00248942P00087842P00085442P00085942P...                 213
# 1     P00285442P00112842P00293242P00289342P00303342P...                 354
# 2     P00193542P00132842P0098342P00010242P00128042P0...                  93
# 3     P00184942P00346142P0097242P00046742P00329542P0...                  33
# 4     P00274942P00251242P00014542P00031342P00145042P...                 659
# ...                                                 ...                 ...
# 5886  P00260042P00144242P00129542P00190242P00121642P...                 114
# 5887  P00242742P00321942P00286642P00286742P00295942P...                  66
# 5888  P00351842P00127642P00182342P00073842P00070442P...                  79
# 5889  P00339342P00034642P00255842P00084842P00302042P...                  40
# 5890  P00000242P00034042P00160042P00306042P00029542P...                  40
#
#       Product_Category_2  Product_Category_3  Purchase  After_discount
# 0                    132                 148    334093       273151.00
# 1                    539                 359    810472       661163.00
# 2                    117                 148    341635       277406.00
# 3                    102                 127    206468       155933.50
# 4                    642                 207    821001       731065.50
# ...                  ...                 ...       ...             ...
# 5886                 125                  20    140990       129841.00
# 5887                  83                  40    108545        89135.00
# 5888                 119                  90    213550       174646.75
# 5889                  36                  16     60182        51062.50
# 5890                  61                  96    152942       115280.50
#
# [5891 rows x 13 columns]

# %%
clean_ds['Stay_In_Current_City_Years']=clean_ds['Stay_In_Current_City_Years'].astype(int)

# %%
clean_ds
# Out:
#       User_ID  Age Gender  City_Category  Stay_In_Current_City_Years  \
# 0     1000001    8      F              0                           2
# 1     1000002   55      M              2                           4
# 2     1000003   30      M              0                           3
# 3     1000004   48      M              1                           2
# 4     1000005   30      M              0                           1
# ...       ...  ...    ...            ...                         ...
# 5886  1004588   30      F              2                           0
# 5887  1004871   21      M              2                           2
# 5888  1004113   40      M              2                           3
# 5889  1005391   30      M              0                           0
# 5890  1001529   21      M              2                           4
#
#       Marital_Status  Occupation  \
# 0                  0          10
# 1                  0          16
# 2                  0          15
# 3                  1           7
# 4                  1          20
# ...              ...         ...
# 5886               0           4
# 5887               0          12
# 5888               0          17
# 5889               0           7
# 5890               1           4
#
#                                              Product_ID  Product_Category_1  \
# 0     P00069042P00248942P00087842P00085442P00085942P...                 213
# 1     P00285442P00112842P00293242P00289342P00303342P...                 354
# 2     P00193542P00132842P0098342P00010242P00128042P0...                  93
# 3     P00184942P00346142P0097242P00046742P00329542P0...                  33
# 4     P00274942P00251242P00014542P00031342P00145042P...                 659
# ...                                                 ...                 ...
# 5886  P00260042P00144242P00129542P00190242P00121642P...                 114
# 5887  P00242742P00321942P00286642P00286742P00295942P...                  66
# 5888  P00351842P00127642P00182342P00073842P00070442P...                  79
# 5889  P00339342P00034642P00255842P00084842P00302042P...                  40
# 5890  P00000242P00034042P00160042P00306042P00029542P...                  40
#
#       Product_Category_2  Product_Category_3  Purchase  After_discount
# 0                    132                 148    334093       273151.00
# 1                    539                 359    810472       661163.00
# 2                    117                 148    341635       277406.00
# 3                    102                 127    206468       155933.50
# 4                    642                 207    821001       731065.50
# ...                  ...                 ...       ...             ...
# 5886                 125                  20    140990       129841.00
# 5887                  83                  40    108545        89135.00
# 5888                 119                  90    213550       174646.75
# 5889                  36                  16     60182        51062.50
# 5890                  61                  96    152942       115280.50
#
# [5891 rows x 13 columns]

# %%
clean_ds.drop('Product_ID',axis=1,inplace=True)

# %%
# clean_ds.drop('City_Category',axis=1,inplace=True)

# %%
#eliminating the age which is less dhan 18
clean_ds = clean_ds[clean_ds['Age'] >= 18]

# %%
clean_ds
# Out:
#       User_ID  Age Gender  City_Category  Stay_In_Current_City_Years  \
# 1     1000002   55      M              2                           4
# 2     1000003   30      M              0                           3
# 3     1000004   48      M              1                           2
# 4     1000005   30      M              0                           1
# 5     1000006   53      F              0                           1
# ...       ...  ...    ...            ...                         ...
# 5886  1004588   30      F              2                           0
# 5887  1004871   21      M              2                           2
# 5888  1004113   40      M              2                           3
# 5889  1005391   30      M              0                           0
# 5890  1001529   21      M              2                           4
#
#       Marital_Status  Occupation  Product_Category_1  Product_Category_2  \
# 1                  0          16                 354                 539
# 2                  0          15                  93                 117
# 3                  1           7                  33                 102
# 4                  1          20                 659                 642
# 5                  0           9                 273                 369
# ...              ...         ...                 ...                 ...
# 5886               0           4                 114                 125
# 5887               0          12                  66                  83
# 5888               0          17                  79                 119
# 5889               0           7                  40                  36
# 5890               1           4                  40                  61
#
#       Product_Category_3  Purchase  After_discount
# 1                    359    810472       661163.00
# 2                    148    341635       277406.00
# 3                    127    206468       155933.50
# 4                    207    821001       731065.50
# 5                    232    379930       320093.00
# ...                  ...       ...             ...
# 5886                  20    140990       129841.00
# 5887                  40    108545        89135.00
# 5888                  90    213550       174646.75
# 5889                  16     60182        51062.50
# 5890                  96    152942       115280.50
#
# [5673 rows x 12 columns]

# %%
# clean_ds['voucher_to_category']=clean_ds[['Product_Category_1','Product_Category_2','Product_Category_3']].max(axis=1)

# %%
# clean_ds.drop('voucher_to_category',axis=1)

# %%
pd.options.mode.copy_on_write = True

# %%
# clean_ds.drop('voucher_to_category',axis=1,inplace=True)

# %%
clean_ds
# Out:
#       User_ID  Age Gender  City_Category  Stay_In_Current_City_Years  \
# 1     1000002   55      M              2                           4
# 2     1000003   30      M              0                           3
# 3     1000004   48      M              1                           2
# 4     1000005   30      M              0                           1
# 5     1000006   53      F              0                           1
# ...       ...  ...    ...            ...                         ...
# 5886  1004588   30      F              2                           0
# 5887  1004871   21      M              2                           2
# 5888  1004113   40      M              2                           3
# 5889  1005391   30      M              0                           0
# 5890  1001529   21      M              2                           4
#
#       Marital_Status  Occupation  Product_Category_1  Product_Category_2  \
# 1                  0          16                 354                 539
# 2                  0          15                  93                 117
# 3                  1           7                  33                 102
# 4                  1          20                 659                 642
# 5                  0           9                 273                 369
# ...              ...         ...                 ...                 ...
# 5886               0           4                 114                 125
# 5887               0          12                  66                  83
# 5888               0          17                  79                 119
# 5889               0           7                  40                  36
# 5890               1           4                  40                  61
#
#       Product_Category_3  Purchase  After_discount
# 1                    359    810472       661163.00
# 2                    148    341635       277406.00
# 3                    127    206468       155933.50
# 4                    207    821001       731065.50
# 5                    232    379930       320093.00
# ...                  ...       ...             ...
# 5886                  20    140990       129841.00
# 5887                  40    108545        89135.00
# 5888                  90    213550       174646.75
# 5889                  16     60182        51062.50
# 5890                  96    152942       115280.50
#
# [5673 rows x 12 columns]

# %% [raw]
# MODEL

# %%
#x and y
x=clean_ds.drop(['Purchase', 'User_ID','Gender','Marital_Status','Occupation'], axis=1)
y=clean_ds['Purchase']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5673 entries, 1 to 5890
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         5673 non-null   int64
#  1   City_Category               5673 non-null   int64
#  2   Stay_In_Current_City_Years  5673 non-null   int64
#  3   Product_Category_1          5673 non-null   int64
#  4   Product_Category_2          5673 non-null   int64
#  5   Product_Category_3          5673 non-null   int64
#  6   After_discount              5673 non-null   float64
# dtypes: float64(1), int64(6)
# memory usage: 354.6 KB

# %%
y
# Out:
# 1       810472
# 2       341635
# 3       206468
# 4       821001
# 5       379930
#          ...
# 5886    140990
# 5887    108545
# 5888    213550
# 5889     60182
# 5890    152942
# Name: Purchase, Length: 5673, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
#not linearly distributed data so linear model is not applicable using d-tree
dtree = DecisionTreeRegressor()
dtree.fit(x_train, y_train)
preds = dtree.predict(x_test)
print(r2_score(preds, y_test))
# Out:
# 0.9895585705091156

# %%
error=mean_absolute_error(preds,y_test)
error
# Out:
# np.float64(33071.9577092511)
